# %% [markdown]
# # Spotify Liked Songs Analysis
#
# This notebook fetches and visualizes data from my Spotify liked songs playlist.

# %% [markdown]
# ## Setup and Initialization

# %% [markdown]
# ### Importations

# %%
import pandas as pd

from gen_Spotify import SpotifyData
from graphs import Graph

# %% [markdown]
# ### Spotify Data Retrieval

# %%
spotify_data = SpotifyData()

if spotify_data.sp:
    spotify_data.get_user_data()
    spotify_data.load_spotify_favorite_songs()
    
    # Convert data to DataFrame for analysis
    df_songs = pd.DataFrame(spotify_data.user_data["favorite_songs"], 
                            columns=["Name", "Artist", "Track ID", "Album", "Duration (ms)", "Release Date", "Artist Country", "Added At"])
    print(df_songs.head())
else:
    print("Failed to set up Spotify API client.")
# Out:
# Data successfully loaded
#                                                 Name        Artist  \
# 0  Connect / Madoka Magica【コネクト / まどか★マギカ】 - Pian...        Relaxu
# 1                          Travailler c'est trop dur  Alpha Blondy
# 2   Elle te rend dingue - poom poom short radio edit        Nuttea
# 3                                             Secret        Louane
# 4                           Solo (feat. Demi Lovato)  Clean Bandit
#
#                  Track ID                               Album  Duration (ms)  \
# 0  6jndVwUMaTMHx5lA5DxGpt  Anime PianoBox Collection, Vol. 19          63433
# 1  4P0hSnVI4TYcLuMuxENnVS                             Best Of         198226
# 2  6Qku7tQdLiYsh31kFbTtId                 Elle Te Rend Dingue         225653
# 3  7dISpxgINJOQSuXUTEfB9x                          Sentiments         191173
# 4  3NuK5xMlSlB6K2Qp16zf3h      What Is Love? (Deluxe Edition)         222706
#
#   Release Date Artist Country              Added At
# 0   2024-01-19        Unknown  2024-09-16T19:17:13Z
# 1   2013-12-02             CI  2024-09-15T14:36:01Z
# 2         2000             FR  2024-09-15T14:34:33Z
# 3   2022-12-09             FR  2024-09-15T14:29:59Z
# 4   2018-11-30             GB  2024-09-15T07:02:48Z

# %% [markdown]
# ## Data Vizualisation

# %%
graph = Graph(spotify_data)

# %%
graph.draw_top_artists(30)

# %%
graph.draw_artist_histogram()

# %%
graph.draw_duration_histogram()

# %%
graph.draw_countries_by_songs()

# %%
graph.draw_countries_by_unique_artists()

# %%
graph.display_artists_by_country("US")
# Out:
# Artists from US:
# Rihanna - 23 songs
# 100 gecs - 20 songs
# Ariana Grande - 19 songs
# Maroon 5 - 13 songs
# Lady Gaga - 13 songs
# Katy Perry - 12 songs
# Black Eyed Peas - 12 songs
# Imagine Dragons - 12 songs
# Britney Spears - 10 songs
# Eminem - 9 songs
# Michael Jackson - 9 songs
# Taylor Swift - 8 songs
# Against The Current - 8 songs
# Madonna - 7 songs
# Beyoncé - 6 songs
# Pitbull - 6 songs
# Jennifer Lopez - 5 songs
# Lana Del Rey - 5 songs
# Alan Walker - 5 songs
# Justin Timberlake - 5 songs
# Lil Nas X - 5 songs
# Pentatonix - 4 songs
# Timbaland - 4 songs
# Miley Cyrus - 4 songs
# Charlie Puth - 4 songs
# Linkin Park - 4 songs
# P!nk - 3 songs
# Skrillex - 3 songs
# Sabrina Carpenter - 3 songs
# Camila Cabello - 3 songs
# Bruno Mars - 3 songs
# Flo Rida - 3 songs
# Nirvana - 3 songs
# Twenty One Pilots - 3 songs
# Chris Tomlin - 3 songs
# Fergie - 3 songs
# TOTO - 3 songs
# Whitney Houston - 3 songs
# Iggy Azalea - 3 songs
# Bon Jovi - 3 songs
# The Pussycat Dolls - 3 songs
# OneRepublic - 3 songs
# Green Day - 3 songs
# Alex Goot - 3 songs
# Billie Eilish - 2 songs
# Guns N' Roses - 2 songs
# Billy Joel - 2 songs
# Slayyyter - 2 songs
# Prince - 2 songs
# A Great Big World - 2 songs
# Michael Sembello - 2 songs
# JAY-Z - 2 songs
# Post Malone - 2 songs
# Elley Duhé - 2 songs
# Doja Cat - 2 songs
# Destiny's Child - 2 songs
# USHER - 2 songs
# Skillet - 2 songs
# Outkast - 2 songs
# Christina Aguilera - 2 songs
# Aerosmith - 2 songs
# Gwen Stefani - 2 songs
# Nicki Minaj - 2 songs
# R.E.M. - 2 songs
# Ava Max - 2 songs
# Owl City - 2 songs
# Mike Posner - 2 songs
# Nelly - 2 songs
# Cyndi Lauper - 2 songs
# Olivia Rodrigo - 2 songs
# 50 Cent - 2 songs
# LMFAO - 2 songs
# Backstreet Boys - 2 songs
# Demi Lovato - 2 songs
# Lizzo - 2 songs
# Macklemore & Ryan Lewis - 2 songs
# Alicia Keys - 2 songs
# Train - 2 songs
# Evanescence - 2 songs
# Kesha - 2 songs
# Anna Kendrick - 1 song
# Kendrick Lamar - 1 song
# Red Hot Chili Peppers - 1 song
# Aesthetic Future - 1 song
# Benson Boone - 1 song
# William Baldé - 1 song
# Lenny Kravitz - 1 song
# The Beach Boys - 1 song
# Simon & Garfunkel - 1 song
# Em Beihold - 1 song
# Witt Lowry - 1 song
# Robert Miles - 1 song
# Yeah Yeah Yeahs - 1 song
# Heidi Montag - 1 song
# Jason Derulo - 1 song
# Gym Class Heroes - 1 song
# Diddy - Dirty Money - 1 song
# AWOLNATION - 1 song
# Tim Burnelis - 1 song
# Santana - 1 song
# Danny McCarthy - 1 song
# BoyWithUke - 1 song
# NF - 1 song
# WILLOW - 1 song
# Coi Leray - 1 song
# DRILL GATES - 1 song
# Les Jones - 1 song
# northwest - 1 song
# Velvet Horizon - 1 song
# James Horner - 1 song
# Mariah Carey - 1 song
# Jeff Buckley - 1 song
# Dr. Dre - 1 song
# Bobby McFerrin - 1 song
# Two Steps from Hell - 1 song
# Kanii - 1 song
# Starship - 1 song
# Enmity - 1 song
# Samuel Barber - 1 song
# Elevation Worship - 1 song
# Lionel Richie - 1 song
# Coolio - 1 song
# Berlin - 1 song
# Marvin Gaye - 1 song
# James Hannigan - 1 song
# John Newman - 1 song
# SICK LEGEND - 1 song
# KC & The Sunshine Band - 1 song
# Jonas Brothers - 1 song
# C & C Music Factory - 1 song
# Daryl Hall & John Oates - 1 song
# pearl - 1 song
# Eagles - 1 song
# Blondie - 1 song
# Marshmello - 1 song
# Kenny Loggins - 1 song
# John Travolta - 1 song
# Earth, Wind & Fire - 1 song
# Bruce Springsteen - 1 song
# Robin S - 1 song
# Van Halen - 1 song
# Ray Parker Jr. - 1 song
# Wes - 1 song
# Scatman John - 1 song
# Cher - 1 song
# Foreigner - 1 song
# Diana Ross - 1 song
# KISS - 1 song
# Kim Carnes - 1 song
# Pharrell Williams - 1 song
# MC Hammer - 1 song
# The Bangles - 1 song
# Belinda Carlisle - 1 song
# Romeo Santos - 1 song
# Kool & The Gang - 1 song
# Donna Summer - 1 song
# Patrick Hernandez - 1 song
# Plain White T's - 1 song
# Village People - 1 song
# Vanessa Carlton - 1 song
# Taylor Dayne - 1 song
# Lipps Inc. - 1 song
# Survivor - 1 song
# MGMT - 1 song
# Miami Sound Machine - 1 song
# X Ambassadors - 1 song
# Creedence Clearwater Revival - 1 song
# Robin Thicke - 1 song
# Capital Cities - 1 song
# Aventura - 1 song
# U.S.A. For Africa - 1 song
# The Pointer Sisters - 1 song
# The Weather Girls - 1 song
# Gloria Gaynor - 1 song
# Irene Cara - 1 song
# Chicago - 1 song
# James Newton Howard - 1 song
# John Mamann - 1 song
# Lauv - 1 song
# Wiz Khalifa - 1 song
# Stevie Wonder - 1 song
# Eve - 1 song
# Lynyrd Skynyrd - 1 song
# The White Stripes - 1 song
# Kelly Clarkson - 1 song
# Lewis Hanton - 1 song
# Meghan Trainor - 1 song
# Hippie Sabotage - 1 song
# Journey - 1 song
# BØRNS - 1 song
# 2Pac - 1 song
# Fugees - 1 song
# Elvis Presley - 1 song
# Metallica - 1 song
# Martin Arteta - 1 song
# DNCE - 1 song
# WALK THE MOON - 1 song
# System Of A Down - 1 song
# Lean & Akai - 1 song
# ROSÉ - 1 song
# Hikaru Station - 1 song
# Goose house - 1 song
# Carole Fredericks - 1 song
# Gnarls Barkley - 1 song
# Jason Mraz - 1 song
# Foster The People - 1 song
# Bob Dylan - 1 song
# Aaron Smith - 1 song
# will.i.am - 1 song
# Fifth Harmony - 1 song
# Selena Gomez & The Scene - 1 song
# Selena Gomez - 1 song
# John Legend - 1 song
# Fall Out Boy - 1 song
# MELON - 1 song
# Metro Boomin - 1 song

# %%
graph.draw_artists_pie_chart_by_country("DE")

# %%
graph.draw_histogram_by_release_year()
# Out:
# 2025-01-25 17:42:17,682 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-25 17:42:17,684 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
graph.draw_histogram_by_add_time("hour")
# Out:
# 2025-01-25 17:42:17,845 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-25 17:42:17,847 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
